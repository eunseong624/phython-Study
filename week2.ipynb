# %% [markdown]
# <a href="https://colab.research.google.com/github/eunseong624/phython-Study/blob/week2/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_address(): #def에 print_address 저장하기?
  print("서울특별시")

# %%
print_address()
# Out:
# 서울특별시

# %%
#값을 반환
def calculate_area(radius):
  area = 3.14*radius**2
  return area
c_area=calculate_area(5.0)

# %%
print(c_area)
# Out:
# 78.5

# %%
def get_sum(S,E):
  sum=0;
  for i in range(S,E+1):
    sum += i
  return sum
print(get_sum(1,10))
# Out:
# 55

# %%
def cal_area():
  result=3.14*r**2
  return result

r=float(input("원의 반지름: "))
area = cal_area()
print(area)
# Out:
# 원의 반지름: 39
# 4775.9400000000005

# %%
def cal_area():
  result=3.14*r**2
  return result
r=float(input("원의 반지름 : "))
area = cal_area()
print(area)
# Out:
# 원의 반지름 : 5
# 78.5

# %%
def cal_area(radius):
  result = 3.14 * radius ** 2
  return result
radius=5
print(cal_area(radius))
# Out:
# 78.5

# %%
def sum(a,b):
  return a+b
sum(1,3)
# Out:
# 4

# %%
x=20       # 전역 변수
def test():
  x=10     # 함수 안에는 변수를 선언하면 안된답니다. (지역 변수)
  print(x)
test()     # 10
print(x)   # 전역 변수 없으면 에라
# Out:
# 10
# 20

# %%
def get_pi():
  return 3.14
print(get_pi())
# Out:
# 3.14

# %%
def print_sum(a,b):
  print(a+b)
print_sum(2,4)
# Out:
# 6

# %%
def sub(a,b):
  return a-b
result = sub(b=3,a=2)
print(result)
# Out:
# -1

# %%
def add_many(*args):
  sum=0
  for i in args:
    sum += i
  print(sum)
add_many(2,3,4,5,7)
# Out:
# 21

# %%
def add_mul(choice,*args):
  if choice == "add":
    result =0
    for i in args:
      result=result+i
  elif choice == "mul":
    result=1
    for i in args:
      result = result*i
  return result

result_add = add_mul('add',1,2,3,4,5)
print(result_add)

result_mul=add_mul('mul',1,2,3,4,5)
print(result_mul)
# Out:
# 15
# 120

# %%
def main(**kw):
  print(type(kw),kw)

main(a=2,b=3)
# Out:
# <class 'dict'> {'a': 2, 'b': 3}

# %%
def introduce(name,age):
  print(f"이름 :  {name} 나이 : {age}")
introduce(age=20,name="홍길동")
# Out:
# 이름 :  홍길동 나이 : 20

# %%
def print_info(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}, {value}")
print_info(name="홍길동", age=20, city="서울")
# Out:
# name, 홍길동
# age, 20
# city, 서울

# %%
def print_order(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}: {value}")

  if "price" in kwargs.keys() and "quantity" in kwargs.keys():
      total = kwargs["price"]*kwargs["quantity"]
      print(f"총 금액 : {total}")

  if (kwargs['quantity']>=3):
    print("대량 주문이다.")

print_order(menu="피자", price=15000, quantity=3, drink="콜라")
# Out:
# menu: 피자
# price: 15000
# quantity: 3
# drink: 콜라
# 총 금액 : 45000
# 대량 주문이다.

# %%
def add(a,b):
  print(a+b)
add(2,3)
# Out:
# 5

# %%
def power(num,exp=2):  # 기본값 설정 할 수 있답니다.
  print(num**exp)

power(3)               # 기본값 exp 2로 들어가고
power(2,3)             # 값을 주었으니 이번엔 exp에 3이 들어갑니다.
# Out:
# 9
# 8

# %%
def calc(**kwargs):
  if(kwargs['op']=="+"):
    print(kwargs["a"]+kwargs["b"])







calc(a=4, b=2, op="*")

# %%
def avg_score(**kwargs):
  sum=0
  count=0
  for i,j in kwargs.items():
    sum+=j
    count += 1
  print(sum/count)


avg_score(math=90, english=80, science=70)
# Out:
# 80.0

# %%
count =0

def increase():
  global count           # global 없으면 아무리 출력해도 1만 나온답니다.
  count += 1
  print(count)
increase()
increase()
increase()
# Out:
# 1
# 2
# 3

# %%
def add_many(*args):
  a=0
  for i in args:
    a += i
  return a

print(add_many(1,2))
# Out:
# 3

# %%
def a_cal(str):
  count = 0;
  for i in str:
    if i in ['a','e','i','o','u']:
      count += 1
  return count
# Out:
# Hello Python
